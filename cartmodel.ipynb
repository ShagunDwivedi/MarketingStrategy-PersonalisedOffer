# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/marketing-strategy-personalised-offer/sample.csv
# /kaggle/input/marketing-strategy-personalised-offer/train_data.csv
# /kaggle/input/marketing-strategy-personalised-offer/test_data.csv

# %%
import numpy as np
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder, \
                                PolynomialFeatures, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import classification_report, f1_score
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier

# %%
# test data
true_data = pd.read_csv('../input/marketing-strategy-personalised-offer/test_data.csv')

# train data raw
train_data = pd.read_csv('../input/marketing-strategy-personalised-offer/train_data.csv')

y_train_all = train_data.pop('Offer Accepted')

# %%
# replacing missing and unnecessary values 

all_col = [i for i in train_data.columns if i not in ["car","restuarant_opposite_direction_house","travelled_more_than_5mins_for_offer"]]

transformer1 = ColumnTransformer(
    [
        ("drop_cols", "drop", ["car","restuarant_opposite_direction_house","travelled_more_than_5mins_for_offer"]),
        ("imputer", SimpleImputer(strategy="most_frequent"), all_col)
    ],
    remainder="passthrough"
)

train_data1 = pd.DataFrame(transformer1.fit_transform(train_data), columns=all_col)
true_data1 = pd.DataFrame(transformer1.transform(true_data), columns=all_col)

# %%
# column names

no_enc = ['travelled_more_than_15mins_for_offer','Prefer western over chinese','travelled_more_than_25mins_for_offer',
              'restuarant_same_direction_house','Cooks regularly','is foodie','has Children','Prefer home food','visit restaurant with rating (avg)']
ord_enc = ['offer expiration','income_range','no_visited_Cold drinks','no_visited_bars','no_Take-aways',
           'Restaur_spend_less_than20','Restaur_spend_greater_than20', 'age','restaurant type','Qualification',
          'Customer type','Marital Status','temperature','Travel Time']

# ord_enc variables

income_list = np.array(['Less than ₹12500', '₹12500 - ₹24999', '₹25000 - ₹37499', 
               '₹37500 - ₹49999', '₹50000 - ₹62499', '₹62500 - ₹74999', 
                '₹75000 - ₹87499', '₹87500 - ₹99999',  '₹100000 or More'])
no_list = np.array(['never', 'less1', '1~3', '4~8', 'gt8'])
offer_list = np.array(['10hours', '2days'])
age_list = np.array(['below21','21', '26', '31', '36', '41', '46','50plus'])
resto_list = np.array(['Cold drinks','Take-away restaurant', 'Restaurant with pub',
              '2 star restaurant','4 star restaurant'])
quali_list = np.array(['Some High School','High School Graduate', 'Some college - no degree','Associates degree',
              'Bachelors degree','Graduate degree (Masters or Doctorate)'])
custo_list = np.array(['Individual', 'With Colleagues', 'With Kids', 'With Family'])
marital_list = np.array([ 'Single', 'Unmarried partner','Married partner', 'Divorced', 'Widowed'])
temp_list = np.array([40, 67, 89])
travel_list = np.array([7, 10, 14, 18, 22])

# %%
# ordinal encoding both test and training data

income_list_oe = OrdinalEncoder(categories=[income_list],dtype=np.int64)
no_list_oe = OrdinalEncoder(categories=[no_list]*5,dtype=np.int64)
offer_list_oe = OrdinalEncoder(categories=[offer_list],dtype=np.int64)
age_list_oe = OrdinalEncoder(categories=[age_list],dtype=np.int64)
resto_list_oe = OrdinalEncoder(categories=[resto_list],dtype=np.int64)
quali_list_oe = OrdinalEncoder(categories=[quali_list],dtype=np.int64)
custo_list_oe = OrdinalEncoder(categories=[custo_list],dtype=np.int64)
marital_list_oe = OrdinalEncoder(categories=[marital_list],dtype=np.int64)
temp_list_oe = OrdinalEncoder(categories=[temp_list],dtype=np.int64)
travel_list_oe = OrdinalEncoder(categories=[travel_list],dtype=np.int64)
one_hot = OneHotEncoder(sparse=False,drop='first', dtype=np.int64)

transformer2 = ColumnTransformer(
    [
        ('offer_list_oe',offer_list_oe,['offer expiration']),
        ('income_list_oe',income_list_oe,['income_range']),
        ('no_list_oe',no_list_oe,['no_visited_Cold drinks','no_visited_bars','no_Take-aways','Restaur_spend_less_than20','Restaur_spend_greater_than20']),
        ('age_list_oe',age_list_oe,['age']),
        ('resto_list_oe',resto_list_oe,['restaurant type']),
        ('quali_list_oe', quali_list_oe,['Qualification']),
        ('custo_list_oe',custo_list_oe,['Customer type']),
        ('marital_list_oe',marital_list_oe,['Marital Status']),
        ('temp_list_oe',temp_list_oe,['temperature']),
        ('travel_list_oe',travel_list_oe,['Travel Time'])
    ],
    remainder="drop"
)

ord_enc_data = pd.DataFrame(transformer2.fit_transform(train_data1), columns=ord_enc)
true_ord_enc_data = pd.DataFrame(transformer2.fit_transform(true_data1), columns=ord_enc)

# %%
# OneHotEncoding both test and train_data

transformer3 = ColumnTransformer(
    [
        ('one_hot1',one_hot,['Job/Job Industry']),
        ('one_hot2',one_hot,['Climate']),
        ('one_hot3',one_hot,['drop location']),
        ('one_hot4',one_hot,['gender'])
    ],
    remainder="drop"
)

one_hot_data = pd.DataFrame(transformer3.fit_transform(train_data1), columns=[name.split("__")[1] for name in transformer3.get_feature_names_out()])
one_hot_list = [name.split("__")[1] for name in transformer3.get_feature_names_out()]
true_one_hot_data = pd.DataFrame(transformer3.transform(true_data1), columns=one_hot_list)

# %%
ss = StandardScaler()
# final full training data

X_train_full = train_data1[no_enc].astype('int64')
X_train_full[one_hot_list] = one_hot_data
X_train_full[ord_enc] = ord_enc_data
X_train_full = pd.DataFrame(ss.fit_transform(X_train_full), columns=X_train_full.columns)

# final full test data

X_true = true_data1[no_enc].astype('int64')
X_true[one_hot_list] = true_one_hot_data
X_true[ord_enc] = true_ord_enc_data
X_true = pd.DataFrame(ss.transform(X_true), columns=X_true.columns)

# final full label

le = LabelEncoder()
y_train_full = le.fit_transform(y_train_all)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_full, y_train_full, test_size=0.25, random_state=32)

# %% [markdown]
# ### Model Building

# %%
# With PCA (seems to reduce the score)

pca = PCA(random_state=32)
reduced_transform_train_df = pca.fit_transform(X_train_full[ord_enc+one_hot_list])

print(pca.explained_variance_ratio_[:5])

reduced_transform_train_df = pd.DataFrame(data = reduced_transform_train_df[:,:4], columns = ["PC1", "PC2", "PC3", "PC4"])
for col in no_enc:
    reduced_transform_train_df[col] = X_train_full[col]
reduced_X_train_com = reduced_transform_train_df.copy()
reduced_y_train_com = y_train_full
reduced_X_train, reduced_X_valid, reduced_y_train, reduced_y_valid = train_test_split(reduced_X_train_com, reduced_y_train_com, test_size=0.3, random_state=32)

model = DecisionTreeClassifier(class_weight="balanced", random_state=32, max_depth=5, ccp_alpha=0.001)
cross_val_score(model, reduced_X_train_com, reduced_y_train_com, cv=5, scoring="f1_micro").mean()
# Out:
# [0.04596689 0.04517007 0.0398681  0.03693941 0.03254303]
# 0.5565048220492486

# %%
# Without PCA

model = DecisionTreeClassifier(class_weight="balanced", random_state=32, ccp_alpha=0.001, max_depth=8)
cross_val_score(model, X_train_full, y_train_full, cv=5, scoring="f1_micro").mean()
# Out:
# 0.5775897912893067

# %%
# Grid search without PCA

param_grid = {
    "ccp_alpha": [0.0001, 0.001, 0.01],
    "max_depth": [5, 10, 15],
    "min_samples_split": [15, 20, 25],
    "min_samples_leaf": [3,5, 10],
    "max_features": ["auto", "log2", None]
}
model = DecisionTreeClassifier(class_weight="balanced", random_state=32)
search = GridSearchCV(model, param_grid=param_grid, scoring="f1_micro", refit=True, cv=5, verbose=3)
search.fit(X_train_full, y_train_full)
search.best_params_
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.583 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.568 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.553 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.583 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.584 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.567 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.583 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.584 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.570 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.582 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.568 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.554 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.582 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.584 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.567 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.582 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.584 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.570 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.560 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.584 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.567 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.560 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.584 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.567 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.580 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.584 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.584 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.570 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.563 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.555 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.543 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.557 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.537 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.524 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.555 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.557 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.531 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.539 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.555 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.543 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.557 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.531 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.543 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.555 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.541 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.557 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.537 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.560 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.555 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.557 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.531 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.560 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.555 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.541 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.557 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.531 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.560 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.557 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.541 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.559 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.554 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.543 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.557 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.554 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.557 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.541 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.559 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.554 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.543 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.582 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.607 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.601 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.572 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.577 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.582 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.607 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.601 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.572 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.577 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.582 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.607 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.601 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.572 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.577 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.583 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.607 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.601 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.572 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.577 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.583 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.607 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.601 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.572 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.577 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.583 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.607 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.601 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.572 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.577 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.582 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.607 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.601 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.571 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.577 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.582 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.607 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.601 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.571 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.577 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.583 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.607 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.601 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.571 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=5, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.577 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.550 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.543 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.559 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.561 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.560 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.570 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.552 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.557 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.546 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.562 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.544 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.561 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.542 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.551 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.549 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.548 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.560 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.548 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.561 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.582 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.571 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.544 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.570 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.566 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.550 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.586 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.555 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.531 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.568 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.568 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.553 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.559 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.544 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.568 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.568 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.553 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.544 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.546 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.556 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.559 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.550 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.566 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.548 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.560 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.555 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.540 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.542 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.530 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.568 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.539 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.525 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.542 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.553 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.547 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.554 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.559 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.530 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.568 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.567 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.563 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.556 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.544 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.558 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.558 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.562 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.557 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.548 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.554 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.550 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.539 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.547 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.559 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.559 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.571 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.541 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.517 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.571 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.517 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.551 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.571 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.563 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.571 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.543 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.583 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.596 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.574 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.567 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.581 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.584 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.596 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.579 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.568 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.584 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.582 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.595 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.580 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.566 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.589 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.578 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.588 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.576 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.567 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.582 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.581 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.592 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.578 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.566 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.578 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.576 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.592 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.582 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.564 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.583 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.569 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.588 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.584 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.555 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.585 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.569 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.588 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.584 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.555 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.585 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.569 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.594 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.586 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.549 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=10, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.590 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.542 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.555 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.535 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.547 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=15;, score=0.532 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.555 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.542 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.554 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.524 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=20;, score=0.562 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.559 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.557 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.561 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.543 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=3, min_samples_split=25;, score=0.545 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.546 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.532 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.543 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.542 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.549 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.546 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.539 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.539 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.544 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.546 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.560 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.552 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.546 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.556 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.559 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.552 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.541 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.536 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.556 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.552 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.536 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.536 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.559 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.555 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.548 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.527 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.550 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.559 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.522 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.541 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.540 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.544 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.522 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.539 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.545 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.553 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.558 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.562 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.574 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.553 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.546 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.535 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.561 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.537 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.561 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.555 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.566 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.529 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.550 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.555 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.564 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.540 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.550 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.0001, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.571 total time=   0.0s
# ...
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=auto, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=log2, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.0s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=3, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=5, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=15;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.565 total time=   0.1s
# [CV 1/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 2/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 3/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 4/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.1s
# [CV 5/5] END ccp_alpha=0.01, max_depth=15, max_features=None, min_samples_leaf=10, min_samples_split=25;, score=0.565 total time=   0.1s
# {'ccp_alpha': 0.0001,
#  'max_depth': 5,
#  'max_features': None,
#  'min_samples_leaf': 5,
#  'min_samples_split': 15}

# %%
# # tuned model

tree_model = DecisionTreeClassifier(class_weight="balanced",random_state=32,ccp_alpha=0.0001,max_depth=5,
                                    max_features=None,min_samples_leaf=5,min_samples_split=15)

tree_model.fit(X_train, y_train)

print(classification_report(y_test, tree_model.predict(X_test)))
print(f1_score(y_test, tree_model.predict(X_test), average='micro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53      1327
#            1       0.64      0.58      0.61      1768
#
#     accuracy                           0.58      3095
#    macro avg       0.57      0.57      0.57      3095
# weighted avg       0.58      0.58      0.58      3095
#
# 0.5751211631663974
